# %%
class Airline:
    # Constructor
    def __init__(self, airline_name, country_of_origin, fleet_size, website, iata_code):
        self.airline_name = airline_name
        self.country_of_origin = country_of_origin
        self.fleet_size = fleet_size
        self.website = website
        self.iata_code = iata_code

    # getter/setter
    def get_airline_name(self):
        return self.airline_name

    def set_airline_name(self, airline_name):
        self.airline_name = airline_name

    def get_country_of_origin(self):
        return self.country_of_origin

    def set_country_of_origin(self, country_of_origin):
        self.country_of_origin = country_of_origin

    def get_fleet_size(self):
        return self.fleet_size

    def set_fleet_size(self, fleet_size):
        self.fleet_size = fleet_size

    def get_website(self):
        return self.website

    def set_website(self, website):
        self.website = website

    def get_iata_code(self):
        return self.iata_code

    def set_iata_code(self, iata_code):
        self.iata_code = iata_code

    def update_website(self, new_website):
        # Update the website of the airline.
        pass

    def increase_fleet_size(self, increment):
        # Increase the fleet size of the airline.
        pass

    def get_info(self):
        # Get information about the airline.
        pass

class Flight:
    # Constructor
    def __init__(self, flight_number, flight_date, flight_time, gate_number, arrival_time,
                 origin, destination, terminal_number, airline):
        self.flight_number = flight_number
        self.flight_date = flight_date
        self.flight_time = flight_time
        self.gate_number = gate_number
        self.arrival_time = arrival_time
        self.origin = origin
        self.destination = destination
        self.terminal_number = terminal_number
        self.airline = airline

    # getter/setter
    def get_flight_number(self):
        return self.flight_number

    def set_flight_number(self, flight_number):
        self.flight_number = flight_number

    def get_flight_date(self):
        return self.flight_date

    def set_flight_date(self, flight_date):
        self.flight_date = flight_date

    def get_flight_time(self):
        return self.flight_time

    def set_flight_time(self, flight_time):
        self.flight_time = flight_time

    def get_gate_number(self):
        return self.gate_number

    def set_gate_number(self, gate_number):
        self.gate_number = gate_number

    def get_arrival_time(self):
        return self.arrival_time

    def set_arrival_time(self, arrival_time):
        self.arrival_time = arrival_time

    def get_origin(self):
        return self.origin

    def set_origin(self, origin):
        self.origin = origin

    def get_destination(self):
        return self.destination

    def set_destination(self, destination):
        self.destination = destination

    def get_terminal_number(self):
        return self.terminal_number

    def set_terminal_number(self, terminal_number):
        self.terminal_number = terminal_number

    def get_airline(self):
        return self.airline

    def set_airline(self, airline):
        self.airline = airline

    def update_gate_number(self, new_gate_number):
        # Update the gate number of the flight.
        pass

    def update_terminal_number(self, new_terminal_number):
        # Update the terminal number of the flight.
        pass

    def get_flight_info(self):
        # Get information about the flight.
        pass

class Passenger:
    # Constructor
    def __init__(self, passenger_name, ticket_type, seat_number, electronic_ticket_id, flight):
        self.passenger_name = passenger_name
        self.ticket_type = ticket_type
        self.seat_number = seat_number
        self.electronic_ticket_id = electronic_ticket_id
        self.flight = flight

    # getter/setter
    def get_passenger_name(self):
        return self.passenger_name

    def set_passenger_name(self, passenger_name):
        self.passenger_name = passenger_name

    def get_ticket_type(self):
        return self.ticket_type

    def set_ticket_type(self, ticket_type):
        self.ticket_type = ticket_type

    def get_seat_number(self):
        return self.seat_number

    def set_seat_number(self, seat_number):
        self.seat_number = seat_number

    def get_electronic_ticket_id(self):
        return self.electronic_ticket_id

    def set_electronic_ticket_id(self, electronic_ticket_id):
        self.electronic_ticket_id = electronic_ticket_id

    def get_flight(self):
        return self.flight

    def set_flight(self, flight):
        self.flight = flight

    def update_seat_number(self, new_seat_number):
        # Update the seat number of the passenger.
        pass

    def update_ticket_type(self, new_ticket_type):
        # Update the ticket type of the passenger.
        pass

    def get_passenger_info(self):
        # Get information about the passenger.
        pass

class BoardingPass:
    # Constructor
    def __init__(self, qrcode, passenger, boarding_till_time):
        self.qrcode = qrcode
        self.passenger = passenger
        self.boarding_status = False  # Whether the passenger has boarded or not
        self.seat_assignment = None
        self.boarding_till_time = boarding_till_time

    # getter/setter
    def get_qrcode(self):
        return self.qrcode

    def set_qrcode(self, qrcode):
        self.qrcode = qrcode

    def get_passenger(self):
        return self.passenger

    def set_passenger(self, passenger):
        self.passenger = passenger

    def is_boarded(self):
        return self.boarding_status

    def set_boarded(self, status):
        self.boarding_status = status

    def get_seat_assignment(self):
        return self.seat_assignment

    def set_seat_assignment(self, seat_assignment):
        self.seat_assignment = seat_assignment

    def get_boarding_till_time(self):
        return self.boarding_till_time

    def set_boarding_till_time(self, boarding_till_time):
        self.boarding_till_time = boarding_till_time

    def mark_boarded(self):
        # Mark the passenger as boarded.
        pass

    def assign_seat(self, seat_number):
        # Assign a seat to the passenger.
        pass

    def update_boarding_till_time(self, new_boarding_till_time):
        # Update the boarding time limit.
        pass

    def get_boarding_pass_info(self):
        # Get information about the boarding pass.
        pass

# Create an Airline object
airline = Airline("National Airlines", "USA", 20, "www.nationalairline.com", 231)

airline.set_airline_name("National Airlines")
airline.set_country_of_origin("USA")
airline.set_fleet_size(20)
airline.set_website("www.nationalairline.com")
airline.set_iata_code(314)

# Create a Flight object
flight = Flight("NA4321", "2020-12-06", "11:40", "03", "13:30", "CHICAGO ORD", "NEW YORK JFK", "2", airline)

flight.set_flight_number("NA4321")
flight.set_flight_date("2020-12-06")
flight.set_flight_time("11:40")
flight.set_gate_number("03")
flight.set_arrival_time("13:30")
flight.set_origin("CHICAGO ORD")
flight.set_destination("NEW YORK JFK")
flight.set_terminal_number("2")

# Create a Passenger object
passenger = Passenger("James Smith", "First Class", "09A", "629", flight)

passenger.set_passenger_name("James Smith")
passenger.set_ticket_type("First Class")
passenger.set_seat_number("09A")
passenger.set_electronic_ticket_id("629")

# Create a BoardingPass object
boarding_pass = BoardingPass("5A6BCD78", passenger, "11:20")

boarding_pass.set_qrcode("5A6BCD78")
boarding_pass.set_boarding_till_time("11:20")

# Display boarding pass details
print("Boarding Pass Details:")
print("QR Code:", boarding_pass.get_qrcode())
print("Boarding Time:", boarding_pass.get_boarding_till_time())

print("Passenger Name:", boarding_pass.passenger.get_passenger_name())
print("Ticket Type:", boarding_pass.passenger.get_ticket_type())
print("Seat Number:", boarding_pass.passenger.get_seat_number())
print("Electronic Ticket ID:", boarding_pass.passenger.get_electronic_ticket_id())

print("Flight Number:", boarding_pass.passenger.flight.get_flight_number())
print("Flight Date:", boarding_pass.passenger.flight.get_flight_date())
print("Flight Time:", boarding_pass.passenger.flight.get_flight_time())
print("Gate Number:", boarding_pass.passenger.flight.get_gate_number())
print("Arrival Time:", boarding_pass.passenger.flight.get_arrival_time())
print("Origin:", boarding_pass.passenger.flight.get_origin())
print("Destination:", boarding_pass.passenger.flight.get_destination())
print("Terminal Number:", boarding_pass.passenger.flight.get_terminal_number())

print("Airline Name:", boarding_pass.passenger.flight.airline.get_airline_name())
